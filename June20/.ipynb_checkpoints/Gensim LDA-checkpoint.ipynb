# %%
import nltk
import re
import numpy as np
import pandas as pd
import pprint as pprint
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy
import pyLDAvis
import pyLDAvis.gensim
import matplotlib.pyplot as plt
# %matplotlib inline
import logging
import pprint
from pprint import pprint
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s", level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore", category = DeprecationWarning)
# Out:
# unable to import 'smart_open.gcs', disabling that module

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stopwords.extend(['from','subject','re','edu','use'])

# %%
df = pd.read_json('https://raw.githubusercontent.com/selva86/datasets/master/newsgroups.json')
print(df.target_names.unique())
df.head()
# Out:
# ['rec.autos' 'comp.sys.mac.hardware' 'comp.graphics' 'sci.space'
#  'talk.politics.guns' 'sci.med' 'comp.sys.ibm.pc.hardware'
#  'comp.os.ms-windows.misc' 'rec.motorcycles' 'talk.religion.misc'
#  'misc.forsale' 'alt.atheism' 'sci.electronics' 'comp.windows.x'
#  'rec.sport.hockey' 'rec.sport.baseball' 'soc.religion.christian'
#  'talk.politics.mideast' 'talk.politics.misc' 'sci.crypt']
#                                              content  target  \
# 0  From: lerxst@wam.umd.edu (where's my thing)\nS...       7
# 1  From: guykuo@carson.u.washington.edu (Guy Kuo)...       4
# 2  From: twillis@ec.ecn.purdue.edu (Thomas E Will...       4
# 3  From: jgreen@amber (Joe Green)\nSubject: Re: W...       1
# 4  From: jcm@head-cfa.harvard.edu (Jonathan McDow...      14
#
#             target_names
# 0              rec.autos
# 1  comp.sys.mac.hardware
# 2  comp.sys.mac.hardware
# 3          comp.graphics
# 4              sci.space

# %%
data = df.content.values.tolist()

# remove emails
data = [re.sub('\S*@\S*\s?','',sent) for sent in data]

# remove new lines
data = [re.sub('\s+',' ', sent) for sent in data]

# remove single quotes
data = [re.sub("\'","",sent) for sent in data]

pprint(data[:1])
# Out:
# ['From: (wheres my thing) Subject: WHAT car is this!? Nntp-Posting-Host: '
#  'rac3.wam.umd.edu Organization: University of Maryland, College Park Lines: '
#  '15 I was wondering if anyone out there could enlighten me on this car I saw '
#  'the other day. It was a 2-door sports car, looked to be from the late 60s/ '
#  'early 70s. It was called a Bricklin. The doors were really small. In '
#  'addition, the front bumper was separate from the rest of the body. This is '
#  'all I know. If anyone can tellme a model name, engine specs, years of '
#  'production, where this car is made, history, or whatever info you have on '
#  'this funky looking car, please e-mail. Thanks, - IL ---- brought to you by '
#  'your neighborhood Lerxst ---- ']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence),deacc=True))
        
data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['from', 'wheres', 'my', 'thing', 'subject', 'what', 'car', 'is', 'this', 'nntp', 'posting', 'host', 'rac', 'wam', 'umd', 'edu', 'organization', 'university', 'of', 'maryland', 'college', 'park', 'lines', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'saw', 'the', 'other', 'day', 'it', 'was', 'door', 'sports', 'car', 'looked', 'to', 'be', 'from', 'the', 'late', 'early', 'it', 'was', 'called', 'bricklin', 'the', 'doors', 'were', 'really', 'small', 'in', 'addition', 'the', 'front', 'bumper', 'was', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', 'this', 'is', 'all', 'know', 'if', 'anyone', 'can', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'of', 'production', 'where', 'this', 'car', 'is', 'made', 'history', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'looking', 'car', 'please', 'mail', 'thanks', 'il', 'brought', 'to', 'you', 'by', 'your', 'neighborhood', 'lerxst']]

# %%
bigram = gensim.models.Phrases(data_words, min_count=5, threshold = 100)
trigram = gensim.models.Phrases(bigram[data_words],threshold=100)

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['from', 'wheres', 'my', 'thing', 'subject', 'what', 'car', 'is', 'this', 'nntp_posting_host', 'rac_wam_umd_edu', 'organization', 'university', 'of', 'maryland_college_park', 'lines', 'was', 'wondering', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'saw', 'the', 'other', 'day', 'it', 'was', 'door', 'sports', 'car', 'looked', 'to', 'be', 'from', 'the', 'late', 'early', 'it', 'was', 'called', 'bricklin', 'the', 'doors', 'were', 'really', 'small', 'in', 'addition', 'the', 'front_bumper', 'was', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', 'this', 'is', 'all', 'know', 'if', 'anyone', 'can', 'tellme', 'model', 'name', 'engine', 'specs', 'years', 'of', 'production', 'where', 'this', 'car', 'is', 'made', 'history', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'looking', 'car', 'please', 'mail', 'thanks', 'il', 'brought', 'to', 'you', 'by', 'your', 'neighborhood', 'lerxst']

# %%
def remove_stopwords(text):
    return[[word for word in simple_preprocess(str(doc)) if word not in stopwords] for doc in text]

def make_bigrams(text):
    return [bigram_mod[doc] for doc in text]

def make_trigrams(text):
    return [trigram_mod[bigram_mod[doc]] for doc in text]

def lemmatization(text, allowed_postags=['NOUN','ADJ','VERB','ADV']):
    texts_out=[]
    for sent in text:
        doc=nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])

        
    return texts_out

# %%
data = remove_stopwords(data_words)

data = make_bigrams(data)

nlp = spacy.load('en_core_web_sm', disable=['parser','ner'])

data = lemmatization(data, allowed_postags=['NOUN','ADJ','VERB','ADV'])

print(data[:1])
# Out:
# [['where', 's', 'thing', 'car', 'nntp_poste', 'host', 'umd', 'organization', 'university', 'maryland_college', 'park', 'line', 'wonder', 'anyone', 'could', 'enlighten', 'car', 'see', 'day', 'door', 'sport', 'car', 'look', 'late', 'early', 'call', 'bricklin', 'door', 'really', 'small', 'addition', 'front_bumper', 'separate', 'rest', 'body', 'know', 'anyone', 'tellme', 'model', 'name', 'engine', 'specs', 'year', 'production', 'car', 'make', 'history', 'info', 'funky', 'look', 'car', 'mail', 'thank', 'bring', 'neighborhood', 'lerxst']]

# %%
id2word = corpora.Dictionary(data)

corpus = [id2word.doc2bow(text) for text in data]

print(corpus[:1])
# Out:
# [[(0, 1), (1, 2), (2, 1), (3, 1), (4, 1), (5, 1), (6, 5), (7, 1), (8, 1), (9, 2), (10, 1), (11, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1), (22, 2), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1), (31, 1), (32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1)]]

# %%
id2word[0]
# Out:
# 'addition'

# %%
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('addition', 1),
#   ('anyone', 2),
#   ('body', 1),
#   ('bricklin', 1),
#   ('bring', 1),
#   ('call', 1),
#   ('car', 5),
#   ('could', 1),
#   ('day', 1),
#   ('door', 2),
#   ('early', 1),
#   ('engine', 1),
#   ('enlighten', 1),
#   ('front_bumper', 1),
#   ('funky', 1),
#   ('history', 1),
#   ('host', 1),
#   ('info', 1),
#   ('know', 1),
#   ('late', 1),
#   ('lerxst', 1),
#   ('line', 1),
#   ('look', 2),
#   ('mail', 1),
#   ('make', 1),
#   ('maryland_college', 1),
#   ('model', 1),
#   ('name', 1),
#   ('neighborhood', 1),
#   ('nntp_poste', 1),
#   ('organization', 1),
#   ('park', 1),
#   ('production', 1),
#   ('really', 1),
#   ('rest', 1),
#   ('s', 1),
#   ('see', 1),
#   ('separate', 1),
#   ('small', 1),
#   ('specs', 1),
#   ('sport', 1),
#   ('tellme', 1),
#   ('thank', 1),
#   ('thing', 1),
#   ('umd', 1),
#   ('university', 1),
#   ('where', 1),
#   ('wonder', 1),
#   ('year', 1)]]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word = id2word,
                                           num_topics=20,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

pprint(lda_model.print_topics())

doc_lda=lda_model[corpus]
# Out:
# [(0,
#   '0.141*"team" + 0.140*"game" + 0.081*"play" + 0.080*"sale" + 0.033*"nhl" + '
#   '0.029*"trade" + 0.029*"cd" + 0.018*"ice" + 0.014*"detroit" + 0.014*"joe"'),
#  (1,
#   '0.086*"pin" + 0.044*"processor" + 0.044*"character" + 0.040*"font" + '
#   '0.034*"mirror" + 0.018*"radius" + 0.018*"quran" + 0.017*"stephen" + '
#   '0.014*"ford" + 0.012*"alot"'),
#  (2,
#   '0.048*"notice" + 0.040*"material" + 0.037*"signal" + 0.037*"external" + '
#   '0.030*"circuit" + 0.022*"case_western" + 0.022*"reserve_university" + '
#   '0.021*"oil" + 0.018*"charle" + 0.016*"william"'),
#  (3,
#   '0.054*"not" + 0.034*"do" + 0.028*"would" + 0.026*"be" + 0.021*"say" + '
#   '0.020*"think" + 0.019*"know" + 0.017*"go" + 0.016*"people" + 0.015*"get"'),
#  (4,
#   '0.084*"library" + 0.061*"object" + 0.045*"cub" + 0.011*"static" + '
#   '0.008*"compiler" + 0.008*"void" + 0.006*"borland" + 0.006*"bc" + '
#   '0.003*"sps" + 0.001*"initialize"'),
#  (5,
#   '0.112*"israel" + 0.061*"israeli" + 0.045*"jew" + 0.038*"arab" + '
#   '0.037*"jewish" + 0.027*"peace" + 0.024*"bomb" + 0.023*"islam" + '
#   '0.023*"muslim" + 0.015*"attack"'),
#  (6,
#   '0.069*"drive" + 0.036*"card" + 0.029*"driver" + 0.028*"mac" + 0.021*"cpu" + '
#   '0.019*"memory" + 0.018*"chip" + 0.016*"machine" + 0.016*"board" + '
#   '0.015*"scsi"'),
#  (7,
#   '0.767*"ax" + 0.058*"max" + 0.006*"icon" + 0.004*"film" + 0.003*"plot" + '
#   '0.003*"catalog" + 0.003*"download" + 0.002*"bmp" + 0.002*"atom" + '
#   '0.002*"wallpaper"'),
#  (8,
#   '0.053*"faq" + 0.036*"ed" + 0.025*"plane" + 0.023*"st" + 0.023*"brown" + '
#   '0.022*"dangerous" + 0.021*"description" + 0.021*"rob" + 0.020*"dual" + '
#   '0.018*"failure"'),
#  (9,
#   '0.028*"system" + 0.020*"car" + 0.019*"use" + 0.018*"new" + 0.016*"computer" '
#   '+ 0.015*"buy" + 0.015*"need" + 0.013*"type" + 0.013*"price" + 0.013*"high"'),
#  (10,
#   '0.051*"god" + 0.032*"evidence" + 0.025*"christian" + 0.022*"reason" + '
#   '0.018*"believe" + 0.017*"claim" + 0.016*"exist" + 0.015*"faith" + '
#   '0.015*"sense" + 0.013*"bible"'),
#  (11,
#   '0.042*"robert" + 0.028*"pa" + 0.028*"illinoi" + 0.027*"channel" + '
#   '0.027*"benefit" + 0.026*"crash" + 0.025*"statistic" + 0.025*"joseph" + '
#   '0.025*"van" + 0.022*"link"'),
#  (12,
#   '0.051*"recommend" + 0.045*"gateway" + 0.042*"usenet" + 0.042*"michigan" + '
#   '0.039*"warranty" + 0.027*"bank" + 0.026*"meg" + 0.024*"probe" + '
#   '0.024*"plug" + 0.018*"sony"'),
#  (13,
#   '0.034*"window" + 0.032*"file" + 0.031*"program" + 0.025*"use" + '
#   '0.020*"software" + 0.019*"information" + 0.016*"copy" + 0.015*"code" + '
#   '0.015*"available" + 0.015*"version"'),
#  (14,
#   '0.019*"time" + 0.017*"year" + 0.014*"first" + 0.013*"may" + 0.010*"back" + '
#   '0.010*"also" + 0.010*"day" + 0.008*"number" + 0.008*"call" + 0.008*"case"'),
#  (15,
#   '0.087*"internet" + 0.071*"bike" + 0.060*"server" + 0.048*"md" + '
#   '0.046*"engine" + 0.038*"ride" + 0.035*"route" + 0.031*"dod" + '
#   '0.029*"announcement" + 0.021*"zone"'),
#  (16,
#   '0.018*"gun" + 0.018*"state" + 0.017*"law" + 0.017*"government" + '
#   '0.017*"people" + 0.015*"kill" + 0.012*"death" + 0.012*"american" + '
#   '0.010*"child" + 0.010*"country"'),
#  (17,
#   '0.088*"line" + 0.080*"organization" + 0.043*"write" + 0.040*"article" + '
#   '0.033*"university" + 0.030*"host" + 0.019*"reply" + 0.018*"nntp_poste" + '
#   '0.016*"thank" + 0.016*"nntp_posting"'),
#  (18,
#   '0.066*"space" + 0.019*"earth" + 0.018*"mount" + 0.016*"launch" + '
#   '0.015*"moon" + 0.015*"research" + 0.015*"mission" + 0.014*"orbit" + '
#   '0.014*"nasa" + 0.012*"satellite"'),
#  (19,
#   '0.148*"key" + 0.042*"encryption" + 0.036*"public" + 0.036*"security" + '
#   '0.033*"clipper" + 0.033*"chip" + 0.026*"government" + 0.025*"secure" + '
#   '0.024*"tap" + 0.021*"pgp"')]

# %%
print('\n Perplexity: ', lda_model.log_perplexity(corpus))

coherence_model_lda = CoherenceModel(model=lda_model, texts=data, dictionary = id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score:', coherence_lda)
# Out:
#  Perplexity:  -14.150704496578369
#
# Coherence Score: 0.4993186780826996

# %%
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
# vis

# %%
# Using Mallet
import os

os.environ['MALLET_HOME'] = 'C:\\Mallet'

mallet_path = 'C:\\Mallet\\bin\\mallet'


ldamallet = gensim.models.wrappers.LdaMallet(mallet_path,corpus=corpus, num_topics=20, id2word=id2word)

# %%
pprint(ldamallet.show_topics(formatted=False))

coherence_model_ldamallet = CoherenceModel(model = ldamallet, texts = data, dictionary = id2word, coherence='c_v')
coherence_ldamallet=coherence_model_ldamallet.get_coherence()
print('\n Coherence score: ',coherence_ldamallet)
# Out:
# [(18,
#   [('file', 0.024193655472785458),
#    ('window', 0.02164415939661926),
#    ('program', 0.015336812333187268),
#    ('display', 0.010994701828466718),
#    ('line', 0.009494217158639738),
#    ('color', 0.008631106507854307),
#    ('set', 0.008551434755474114),
#    ('server', 0.007661766853895285),
#    ('run', 0.0075157019745315965),
#    ('application', 0.007409472971358005)]),
#  (8,
#   [('god', 0.025345535344405527),
#    ('christian', 0.018918138565636025),
#    ('people', 0.010984320666842415),
#    ('bible', 0.009540667093485984),
#    ('man', 0.009314703925482368),
#    ('church', 0.007958924917460676),
#    ('book', 0.007732961749457061),
#    ('love', 0.006954644170777941),
#    ('word', 0.006691020474773723),
#    ('religion', 0.006339522213434766)]),
#  (1,
#   [('write', 0.12638956928062706),
#    ('article', 0.10946979688736481),
#    ('line', 0.10468402607679843),
#    ('organization', 0.10042582055243622),
#    ('host', 0.06187587142480311),
#    ('nntp_posting', 0.03672231224328296),
#    ('nntp_poste', 0.03562949843614576),
#    ('reply', 0.03155970908542789),
#    ('university', 0.017974902965670572),
#    ('distribution_world', 0.014338470814334703)]),
#  (12,
#   [('time', 0.03647096447512192),
#    ('good', 0.035458252271939876),
#    ('thing', 0.029262052607733922),
#    ('make', 0.027556432055006262),
#    ('problem', 0.02117368014284572),
#    ('point', 0.018468672547504197),
#    ('find', 0.017589211950003996),
#    ('bad', 0.015803640433867228),
#    ('lot', 0.014710977267276071),
#    ('give', 0.014137995362844121)]),
#  (14,
#   [('drive', 0.02373727347494399),
#    ('card', 0.018589943563710614),
#    ('system', 0.015569609483565412),
#    ('problem', 0.013442613652477241),
#    ('driver', 0.013400073735855477),
#    ('window', 0.012790334930943534),
#    ('scsi', 0.012535095431212956),
#    ('mac', 0.010989478460622218),
#    ('run', 0.010663339099855364),
#    ('work', 0.01020957998922322)]),
#  (15,
#   [('bike', 0.012541761206295892),
#    ('organization', 0.010737319779179248),
#    ('good', 0.01057652796884212),
#    ('line', 0.009844031943972986),
#    ('back', 0.00834330838082647),
#    ('ride', 0.00793239597663159),
#    ('article', 0.007467886302324335),
#    ('leave', 0.006985510871312954),
#    ('dod', 0.0068783163310882035),
#    ('road', 0.0068783163310882035)]),
#  (4,
#   [('space', 0.024745701238109367),
#    ('launch', 0.007468222958603294),
#    ('research', 0.006957152513312561),
#    ('earth', 0.006808777222744283),
#    ('year', 0.006627429645383056),
#    ('system', 0.006528512785004204),
#    ('nasa', 0.006413109781228877),
#    ('project', 0.006033928483109946),
#    ('satellite', 0.0058031224755592924),
#    ('center', 0.005687719471783966)]),
#  (16,
#   [('game', 0.025914198956684228),
#    ('team', 0.01901066673587501),
#    ('year', 0.016545119514157432),
#    ('play', 0.015247463081674496),
#    ('player', 0.012587267395084478),
#    ('win', 0.011743790713970569),
#    ('season', 0.00809737613869352),
#    ('hockey', 0.007214969764605123),
#    ('fan', 0.006708883755936778),
#    ('good', 0.005878383639147699)]),
#  (17,
#   [('car', 0.027098025112191764),
#    ('power', 0.00928807092708708),
#    ('buy', 0.008177880631088456),
#    ('high', 0.0073647835128922805),
#    ('work', 0.006817506606414086),
#    ('ground', 0.006410958047315998),
#    ('wire', 0.006082591903429081),
#    ('engine', 0.006020045971260144),
#    ('low', 0.005832408174753334),
#    ('light', 0.005410223132613013)]),
#  (19,
#   [('key', 0.030662401498010455),
#    ('system', 0.012530233283919794),
#    ('encryption', 0.01107903565576968),
#    ('information', 0.009034875555902317),
#    ('security', 0.008941249902473278),
#    ('message', 0.008847624249044238),
#    ('chip', 0.008832019973472731),
#    ('bit', 0.008176640399469455),
#    ('technology', 0.008051806194897402),
#    ('government', 0.007911367714753842)])]
#
#  Coherence score:  0.6426705057513906

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    coherence_values = []
    model_list=[]
    
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path,corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherenceModel = CoherenceModel(model=model,texts = texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherenceModel.get_coherence())
        
    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus,texts=data, start=2, limit=40,step=6)

# %%
limit=40;start=2;step=6;

x = range(start, limit,step)
plt.plot(x, coherence_values)
plt.xlabel('Num topics')
plt.ylabel('Coherence score')
plt.legend(("coherence_values"),loc='best')
plt.show()

# %%
for m, cv in zip(x, coherence_values):
    print("Num topics = ",m," has Coherence Value of: ", round(cv,4))
# Out:
# Num topics =  2  has Coherence Value of:  0.4817
# Num topics =  8  has Coherence Value of:  0.5798
# Num topics =  14  has Coherence Value of:  0.6224
# Num topics =  20  has Coherence Value of:  0.6276
# Num topics =  26  has Coherence Value of:  0.6535
# Num topics =  32  has Coherence Value of:  0.6449
# Num topics =  38  has Coherence Value of:  0.6298

# %%
optimal_model = model_list[3]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.025*"game" + 0.019*"team" + 0.015*"play" + 0.015*"year" + 0.012*"player" '
#   '+ 0.012*"win" + 0.008*"season" + 0.007*"hockey" + 0.007*"fan" + '
#   '0.007*"good"'),
#  (1,
#   '0.028*"car" + 0.015*"article" + 0.014*"line" + 0.013*"write" + 0.012*"bike" '
#   '+ 0.012*"organization" + 0.008*"drive" + 0.007*"ride" + 0.007*"buy" + '
#   '0.007*"good"'),
#  (2,
#   '0.030*"file" + 0.024*"post" + 0.019*"send" + 0.016*"mail" + 0.015*"list" + '
#   '0.015*"address" + 0.014*"line" + 0.013*"information" + 0.012*"read" + '
#   '0.011*"email"'),
#  (3,
#   '0.008*"article" + 0.007*"food" + 0.007*"study" + 0.006*"organization" + '
#   '0.006*"research" + 0.006*"line" + 0.006*"water" + 0.006*"doctor" + '
#   '0.006*"disease" + 0.006*"medical"'),
#  (4,
#   '0.012*"make" + 0.010*"year" + 0.010*"work" + 0.010*"money" + '
#   '0.010*"president" + 0.008*"people" + 0.007*"program" + 0.007*"american" + '
#   '0.007*"job" + 0.007*"pay"'),
#  (5,
#   '0.014*"people" + 0.012*"question" + 0.010*"exist" + 0.010*"write" + '
#   '0.010*"reason" + 0.009*"make" + 0.009*"argument" + 0.009*"claim" + '
#   '0.009*"evidence" + 0.008*"true"'),
#  (6,
#   '0.030*"time" + 0.024*"problem" + 0.021*"good" + 0.019*"point" + '
#   '0.018*"make" + 0.016*"number" + 0.016*"find" + 0.014*"book" + 0.013*"give" '
#   '+ 0.012*"thing"'),
#  (7,
#   '0.091*"write" + 0.062*"article" + 0.043*"line" + 0.035*"organization" + '
#   '0.020*"good" + 0.015*"make" + 0.014*"thing" + 0.012*"hear" + 0.009*"bad" + '
#   '0.009*"guess"'),
#  (8,
#   '0.031*"key" + 0.014*"system" + 0.011*"encryption" + 0.010*"bit" + '
#   '0.009*"security" + 0.009*"technology" + 0.009*"chip" + 0.008*"message" + '
#   '0.008*"information" + 0.008*"public"'),
#  (9,
#   '0.863*"ax" + 0.059*"max" + 0.002*"qax" + 0.002*"qq" + 0.001*"mb" + '
#   '0.001*"giz" + 0.001*"mf" + 0.001*"bs" + 0.001*"mq" + 0.001*"tm"'),
#  (10,
#   '0.029*"god" + 0.019*"christian" + 0.010*"bible" + 0.009*"people" + '
#   '0.008*"word" + 0.008*"church" + 0.007*"faith" + 0.007*"love" + 0.006*"man" '
#   '+ 0.006*"jesus"'),
#  (11,
#   '0.021*"gun" + 0.018*"state" + 0.016*"law" + 0.014*"people" + '
#   '0.009*"government" + 0.008*"crime" + 0.007*"case" + 0.007*"weapon" + '
#   '0.007*"firearm" + 0.006*"kill"'),
#  (12,
#   '0.018*"people" + 0.017*"time" + 0.012*"day" + 0.011*"leave" + 0.011*"back" '
#   '+ 0.011*"happen" + 0.010*"start" + 0.008*"call" + 0.008*"live" + '
#   '0.008*"home"'),
#  (13,
#   '0.020*"line" + 0.017*"sale" + 0.013*"organization" + 0.012*"price" + '
#   '0.012*"sell" + 0.009*"power" + 0.009*"work" + 0.009*"box" + 0.007*"ground" '
#   '+ 0.007*"wire"'),
#  (14,
#   '0.097*"line" + 0.097*"organization" + 0.074*"university" + 0.072*"host" + '
#   '0.041*"nntp_poste" + 0.039*"nntp_posting" + 0.029*"article" + 0.028*"reply" '
#   '+ 0.025*"write" + 0.013*"distribution_world"'),
#  (15,
#   '0.024*"drive" + 0.019*"card" + 0.016*"system" + 0.016*"problem" + '
#   '0.013*"window" + 0.013*"scsi" + 0.013*"driver" + 0.011*"bit" + 0.011*"mac" '
#   '+ 0.010*"run"'),
#  (16,
#   '0.025*"space" + 0.008*"research" + 0.007*"launch" + 0.007*"system" + '
#   '0.007*"earth" + 0.006*"nasa" + 0.006*"datum" + 0.006*"satellite" + '
#   '0.006*"technology" + 0.006*"year"'),
#  (17,
#   '0.034*"organization" + 0.023*"line" + 0.022*"_" + 0.013*"ca" + 0.007*"ed" + '
#   '0.006*"air" + 0.006*"reply" + 0.006*"md" + 0.005*"te" + 0.005*"tom"'),
#  (18,
#   '0.019*"window" + 0.012*"image" + 0.012*"program" + 0.011*"file" + '
#   '0.010*"version" + 0.010*"display" + 0.009*"server" + 0.009*"run" + '
#   '0.009*"software" + 0.009*"application"'),
#  (19,
#   '0.014*"armenian" + 0.012*"israel" + 0.010*"people" + 0.009*"israeli" + '
#   '0.009*"war" + 0.008*"jew" + 0.007*"arab" + 0.007*"turkish" + '
#   '0.006*"government" + 0.006*"attack"')]

# %%
# find dominant topic in each sentence

def format_topic_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
    sent_topics_df= pd.DataFrame()
    
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key = lambda x: (x[1]), reverse=True)
        
        for j, (topic_num, prop_topic) in enumerate(row):
            if j==0:
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df =sent_topics_df.append(pd.Series([int(topic_num),round(prop_topic,4),
                                                                topic_keywords]),ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic','Perc_Contribution','Topic_Keywords']
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return sent_topics_df

df_topic_sents_keywords = format_topic_sentences(ldamodel=optimal_model, corpus = corpus, texts = data)

df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns=['Document_No','Dominant_Topic','Topic_Perc_Contrib','Keywords','Text']

df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             1.0              0.1655
# 1            1            15.0              0.1909
# 2            2            15.0              0.1579
# 3            3             7.0              0.1184
# 4            4            16.0              0.1166
# 5            5            11.0              0.4430
# 6            6             3.0              0.1309
# 7            7            15.0              0.5642
# 8            8            18.0              0.1052
# 9            9            15.0              0.2249
#
#                                             Keywords  \
# 0  car, article, line, write, bike, organization,...
# 1  drive, card, system, problem, window, scsi, dr...
# 2  drive, card, system, problem, window, scsi, dr...
# 3  write, article, line, organization, good, make...
# 4  space, research, launch, system, earth, nasa, ...
# 5  gun, state, law, people, government, crime, ca...
# 6  article, food, study, organization, research, ...
# 7  drive, card, system, problem, window, scsi, dr...
# 8  window, image, program, file, version, display...
# 9  drive, card, system, problem, window, scsi, dr...
#
#                                                 Text
# 0  [where, s, thing, car, nntp_poste, host, umd, ...
# 1  [clock, poll, final, call, summary, final, cal...
# 2  [thomas, willis, question, organization, purdu...
# 3  [joe, green, weitek, organization, harris, com...
# 4  [mcdowell, shuttle_launch, question, organizat...
# 5  [foxvog_douglas, reword, second_amendment, ide...
# 6  [brian, man, delaney, brain, tumor, treatment,...
# 7  [grubb, ide_vs, scsi, organization, state, uni...
# 8  [win, icon, help, organization, university, no...
# 9  [stan_kerr, sigma_designs, double, article, or...

# %%
# most represenatative document for each topic

sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, grp.sort_values(['Perc_Contribution'],
                                                                                         ascending=[0]).head(1)],
                                           axis=0)
    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

sent_topics_sorteddf_mallet.columns=['Topic_Num','Topic_Perc_Contrib','Keywords','Text']

sent_topics_sorteddf_mallet
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.9345
# 1         1.0              0.5596
# 2         2.0              0.9725
# 3         3.0              0.7329
# 4         4.0              0.8258
# 5         5.0              0.6653
# 6         6.0              0.5969
# 7         7.0              0.7175
# 8         8.0              0.9085
# 9         9.0              0.9959
# 10       10.0              0.7786
# 11       11.0              0.7154
# 12       12.0              0.9032
# 13       13.0              0.6822
# 14       14.0              0.5103
# 15       15.0              0.8239
# 16       16.0              0.8342
# 17       17.0              0.9793
# 18       18.0              0.7708
# 19       19.0              0.7803
#
#                                              Keywords  \
# 0   game, team, play, year, player, win, season, h...
# 1   car, article, line, write, bike, organization,...
# 2   file, post, send, mail, list, address, line, i...
# 3   article, food, study, organization, research, ...
# 4   make, year, work, money, president, people, pr...
# 5   people, question, exist, write, reason, make, ...
# 6   time, problem, good, point, make, number, find...
# 7   write, article, line, organization, good, make...
# 8   key, system, encryption, bit, security, techno...
# 9           ax, max, qax, qq, mb, giz, mf, bs, mq, tm
# 10  god, christian, bible, people, word, church, f...
# 11  gun, state, law, people, government, crime, ca...
# 12  people, time, day, leave, back, happen, start,...
# 13  line, sale, organization, price, sell, power, ...
# 14  line, organization, university, host, nntp_pos...
# 15  drive, card, system, problem, window, scsi, dr...
# 16  space, research, launch, system, earth, nasa, ...
# 17  organization, line, _, ca, ed, air, reply, md,...
# 18  window, image, program, file, version, display...
# 19  armenian, israel, people, israeli, war, jew, a...
#
#                                                  Text
# 0   [rocket, nhl, final, point, standing, organiza...
# 1   [demostheni, article, apr, organization, lehig...
# 2   [landon_noll, reposte, international_obfuscate...
# 3   [prevent, kidney_stone, formation, line, nntp_...
# 4   [clinton_gore, clinton, background, briefing, ...
# 5   [faq, constructing_logical, argument, summary,...
# 6   [alan, christiansen, sphere, point, organizati...
# 7   [jeff, mason, marvel, dc, valiant, image, sale...
# 8   [clipper_chip, announcement, text, white_house...
# 9   [cliff, reply, cliff, organization, university...
# 10  [robert_weiss, ld, rick, reply, organization, ...
# 11  [larry_cipriani, ohio, house, bill, otto, beat...
# 12  [david_davidian, account, anti, armenian, huma...
# 13  [ground, power, wiring, question, wiring, line...
# 14  [steve_lamont, finding, equally, space, point,...
# 15  [keith, rice, drive, controller, compatibility...
# 16  [jon_leech, space, faq, upcoming, planetary_pr...
# 17  [roman, cliff, reply, cliff, organization, uni...
# 18  [david, lewis, comp, window, frequently_aske, ...
# 19  [center, policy_research, final_solution, gaza...

# %%
# topic distribution accross documents
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

topic_contribution = round(topic_counts/topic_counts.sum(),4)

topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic','Topic_Keywords']]

df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis =1)

df_dominant_topics.columns=['Dominant_Topic','Topic_Keywords','Num_Documents','Perc_Documents']

df_dominant_topics
# Out:
#          Dominant_Topic                                     Topic_Keywords  \
# 0.0                 1.0  car, article, line, write, bike, organization,...
# 1.0                15.0  drive, card, system, problem, window, scsi, dr...
# 2.0                15.0  drive, card, system, problem, window, scsi, dr...
# 3.0                 7.0  write, article, line, organization, good, make...
# 4.0                16.0  space, research, launch, system, earth, nasa, ...
# ...                 ...                                                ...
# 11309.0             3.0  article, food, study, organization, research, ...
# 11310.0            15.0  drive, card, system, problem, window, scsi, dr...
# 11311.0            15.0  drive, card, system, problem, window, scsi, dr...
# 11312.0             6.0  time, problem, good, point, make, number, find...
# 11313.0             1.0  car, article, line, write, bike, organization,...
#
#          Num_Documents  Perc_Documents
# 0.0             1063.0          0.0940
# 1.0             1065.0          0.0941
# 2.0              221.0          0.0195
# 3.0              517.0          0.0457
# 4.0              298.0          0.0263
# ...                ...             ...
# 11309.0            NaN             NaN
# 11310.0            NaN             NaN
# 11311.0            NaN             NaN
# 11312.0            NaN             NaN
# 11313.0            NaN             NaN
#
# [11314 rows x 4 columns]
